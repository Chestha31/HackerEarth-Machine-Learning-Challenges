# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %%
train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')

# %%
train
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# 1                     Yes          1.0                  2.0
# 2                     Yes          2.0                  NaN
# 3                     Yes          1.0                  1.0
# 4                      No          3.0                  7.0
# ...                   ...          ...                  ...
# 22745                  No          1.0                  3.0
# 22746                 Yes          3.0                  6.0
# 22747                 Yes          3.0                  7.0
# 22748                  No          2.0                  5.0
# 22749                  No          3.0                  6.0
#
#        Mental Fatigue Score  Burn Rate
# 0                       3.8       0.16
# 1                       5.0       0.36
# 2                       5.8       0.49
# 3                       2.6       0.20
# 4                       6.9       0.52
# ...                     ...        ...
# 22745                   NaN       0.41
# 22746                   6.7       0.59
# 22747                   NaN       0.72
# 22748                   5.9       0.52
# 22749                   7.8       0.61
#
# [22750 rows x 9 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  object
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  float64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.6+ MB

# %%
train.describe()
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score     Burn Rate
# count  22750.000000         21369.000000          20633.000000  21626.000000
# mean       2.178725             4.481398              5.728188      0.452005
# std        1.135145             2.047211              1.920839      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.600000      0.310000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %%
plt.figure(figsize=(10,6))
sns.boxplot(train['Burn Rate'])
plt.title("Burn Rate")
plt.show()
# Out:
# C:\Users\Chestha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# 1                     Yes          1.0                  2.0
# 2                     Yes          2.0                  NaN
# 3                     Yes          1.0                  1.0
# 4                      No          3.0                  7.0
# ...                   ...          ...                  ...
# 22745                  No          1.0                  3.0
# 22746                 Yes          3.0                  6.0
# 22747                 Yes          3.0                  7.0
# 22748                  No          2.0                  5.0
# 22749                  No          3.0                  6.0
#
#        Mental Fatigue Score  Burn Rate
# 0                       3.8       0.16
# 1                       5.0       0.36
# 2                       5.8       0.49
# 3                       2.6       0.20
# 4                       6.9       0.52
# ...                     ...        ...
# 22745                   NaN       0.41
# 22746                   6.7       0.59
# 22747                   NaN       0.72
# 22748                   5.9       0.52
# 22749                   7.8       0.61
#
# [22750 rows x 9 columns]

# %%
train['Date of Joining'] = pd.to_datetime(train['Date of Joining'])

# %%
def get_y_m(df):
    df['Year of Joining'] = df['Date of Joining'].dt.year
    df['Month of Joining'] = df['Date of Joining'].dt.month
    df['Day of Joining'] = df['Date of Joining'].dt.day
    return df

# %%
train = get_y_m(train)

# %%
train
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# 1                     Yes          1.0                  2.0
# 2                     Yes          2.0                  NaN
# 3                     Yes          1.0                  1.0
# 4                      No          3.0                  7.0
# ...                   ...          ...                  ...
# 22745                  No          1.0                  3.0
# 22746                 Yes          3.0                  6.0
# 22747                 Yes          3.0                  7.0
# 22748                  No          2.0                  5.0
# 22749                  No          3.0                  6.0
#
#        Mental Fatigue Score  Burn Rate  Year of Joining  Month of Joining  \
# 0                       3.8       0.16             2008                 9
# 1                       5.0       0.36             2008                11
# 2                       5.8       0.49             2008                 3
# 3                       2.6       0.20             2008                11
# 4                       6.9       0.52             2008                 7
# ...                     ...        ...              ...               ...
# 22745                   NaN       0.41             2008                12
# 22746                   6.7       0.59             2008                 1
# 22747                   NaN       0.72             2008                11
# 22748                   5.9       0.52             2008                 1
# 22749                   7.8       0.61             2008                 1
#
#        Day of Joining
# 0                  30
# 1                  30
# 2                  10
# 3                   3
# 4                  24
# ...               ...
# 22745              30
# 22746              19
# 22747               5
# 22748              10
# 22749               6
#
# [22750 rows x 12 columns]

# %%
train.drop(columns=['Date of Joining'], inplace = True)

# %%
train.head()
# Out:
#                 Employee ID  Gender Company Type WFH Setup Available  \
# 0  fffe32003000360033003200  Female      Service                  No
# 1      fffe3700360033003500    Male      Service                 Yes
# 2  fffe31003300320037003900  Female      Product                 Yes
# 3  fffe32003400380032003900    Male      Service                 Yes
# 4  fffe31003900340031003600  Female      Service                  No
#
#    Designation  Resource Allocation  Mental Fatigue Score  Burn Rate  \
# 0          2.0                  3.0                   3.8       0.16
# 1          1.0                  2.0                   5.0       0.36
# 2          2.0                  NaN                   5.8       0.49
# 3          1.0                  1.0                   2.6       0.20
# 4          3.0                  7.0                   6.9       0.52
#
#    Year of Joining  Month of Joining  Day of Joining
# 0             2008                 9              30
# 1             2008                11              30
# 2             2008                 3              10
# 3             2008                11               3
# 4             2008                 7              24

# %%
train['Company Type'].value_counts()
# Out:
# Service    14833
# Product     7917
# Name: Company Type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
train['WFH Setup Available'] = le.fit_transform(train['WFH Setup Available'])
train['Company Type'] = le.fit_transform(train['Company Type'])
train['Gender'] = le.fit_transform(train['Gender'])

# %%
train
# Out:
#                     Employee ID  Gender  Company Type  WFH Setup Available  \
# 0      fffe32003000360033003200       0             1                    0
# 1          fffe3700360033003500       1             1                    1
# 2      fffe31003300320037003900       0             0                    1
# 3      fffe32003400380032003900       1             1                    1
# 4      fffe31003900340031003600       0             1                    0
# ...                         ...     ...           ...                  ...
# 22745  fffe31003500370039003100       0             1                    0
# 22746  fffe33003000350031003800       0             0                    1
# 22747          fffe390032003000       1             1                    1
# 22748  fffe33003300320036003900       0             1                    0
# 22749      fffe3400350031003800       1             0                    0
#
#        Designation  Resource Allocation  Mental Fatigue Score  Burn Rate  \
# 0              2.0                  3.0                   3.8       0.16
# 1              1.0                  2.0                   5.0       0.36
# 2              2.0                  NaN                   5.8       0.49
# 3              1.0                  1.0                   2.6       0.20
# 4              3.0                  7.0                   6.9       0.52
# ...            ...                  ...                   ...        ...
# 22745          1.0                  3.0                   NaN       0.41
# 22746          3.0                  6.0                   6.7       0.59
# 22747          3.0                  7.0                   NaN       0.72
# 22748          2.0                  5.0                   5.9       0.52
# 22749          3.0                  6.0                   7.8       0.61
#
#        Year of Joining  Month of Joining  Day of Joining
# 0                 2008                 9              30
# 1                 2008                11              30
# 2                 2008                 3              10
# 3                 2008                11               3
# 4                 2008                 7              24
# ...                ...               ...             ...
# 22745             2008                12              30
# 22746             2008                 1              19
# 22747             2008                11               5
# 22748             2008                 1              10
# 22749             2008                 1               6
#
# [22750 rows x 11 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Gender                22750 non-null  int32
#  2   Company Type          22750 non-null  int32
#  3   WFH Setup Available   22750 non-null  int32
#  4   Designation           22750 non-null  float64
#  5   Resource Allocation   21369 non-null  float64
#  6   Mental Fatigue Score  20633 non-null  float64
#  7   Burn Rate             21626 non-null  float64
#  8   Year of Joining       22750 non-null  int64
#  9   Month of Joining      22750 non-null  int64
#  10  Day of Joining        22750 non-null  int64
# dtypes: float64(4), int32(3), int64(3), object(1)
# memory usage: 1.6+ MB

# %%
train.describe()
# Out:
#              Gender  Company Type  WFH Setup Available   Designation  \
# count  22750.000000  22750.000000         22750.000000  22750.000000
# mean       0.476571      0.652000             0.540220      2.178725
# std        0.499462      0.476346             0.498391      1.135145
# min        0.000000      0.000000             0.000000      0.000000
# 25%        0.000000      0.000000             0.000000      1.000000
# 50%        0.000000      1.000000             1.000000      2.000000
# 75%        1.000000      1.000000             1.000000      3.000000
# max        1.000000      1.000000             1.000000      5.000000
#
#        Resource Allocation  Mental Fatigue Score     Burn Rate  \
# count         21369.000000          20633.000000  21626.000000
# mean              4.481398              5.728188      0.452005
# std               2.047211              1.920839      0.198226
# min               1.000000              0.000000      0.000000
# 25%               3.000000              4.600000      0.310000
# 50%               4.000000              5.900000      0.450000
# 75%               6.000000              7.100000      0.590000
# max              10.000000             10.000000      1.000000
#
#        Year of Joining  Month of Joining  Day of Joining
# count          22750.0      22750.000000    22750.000000
# mean            2008.0          6.509978       15.760659
# std                0.0          3.440477        8.769239
# min             2008.0          1.000000        1.000000
# 25%             2008.0          4.000000        8.000000
# 50%             2008.0          7.000000       16.000000
# 75%             2008.0          9.000000       23.000000
# max             2008.0         12.000000       31.000000

# %%
mean1 = train.groupby('Company Type').mean()['Resource Allocation'].round().loc[0]
mean2 = train.groupby('Company Type').mean()['Resource Allocation'].round().loc[1]
train.loc[train['Company Type']==0, 'Resource Allocation'] = train.loc[train['Company Type']==0, 'Resource Allocation'].fillna(value=mean1)
train.loc[train['Company Type']==1, 'Resource Allocation'] = train.loc[train['Company Type']==1, 'Resource Allocation'].fillna(value=mean2)

# %%
mean1 = round((train.groupby('Company Type').mean()['Mental Fatigue Score'].loc[0]), 1)
mean2 = round((train.groupby('Company Type').mean()['Mental Fatigue Score'].loc[1]), 1)
train.loc[train['Company Type']==0, 'Mental Fatigue Score'] = train.loc[train['Company Type']==0, 'Mental Fatigue Score'].fillna(value=mean1)
train.loc[train['Company Type']==1, 'Mental Fatigue Score'] = train.loc[train['Company Type']==1, 'Mental Fatigue Score'].fillna(value=mean2)

# %%
s=0
for i in range(len(train['Burn Rate'])):
    if (train['Burn Rate'][i]<0):
        print(train['Burn Rate'][i])
        s+=1
print(s)
# Out:
# 0

# %%
train = train[train['Burn Rate']>=0]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21626 entries, 0 to 22749
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           21626 non-null  object
#  1   Gender                21626 non-null  int32
#  2   Company Type          21626 non-null  int32
#  3   WFH Setup Available   21626 non-null  int32
#  4   Designation           21626 non-null  float64
#  5   Resource Allocation   21626 non-null  float64
#  6   Mental Fatigue Score  21626 non-null  float64
#  7   Burn Rate             21626 non-null  float64
#  8   Year of Joining       21626 non-null  int64
#  9   Month of Joining      21626 non-null  int64
#  10  Day of Joining        21626 non-null  int64
# dtypes: float64(4), int32(3), int64(3), object(1)
# memory usage: 1.7+ MB

# %%
train.drop(columns = ['Employee ID'], inplace = True)
# Out:
# C:\Users\Chestha\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
train
# Out:
#        Gender  Company Type  WFH Setup Available  Designation  \
# 0           0             1                    0          2.0
# 1           1             1                    1          1.0
# 2           0             0                    1          2.0
# 3           1             1                    1          1.0
# 4           0             1                    0          3.0
# ...       ...           ...                  ...          ...
# 22745       0             1                    0          1.0
# 22746       0             0                    1          3.0
# 22747       1             1                    1          3.0
# 22748       0             1                    0          2.0
# 22749       1             0                    0          3.0
#
#        Resource Allocation  Mental Fatigue Score  Burn Rate  Year of Joining  \
# 0                      3.0                   3.8       0.16             2008
# 1                      2.0                   5.0       0.36             2008
# 2                      4.0                   5.8       0.49             2008
# 3                      1.0                   2.6       0.20             2008
# 4                      7.0                   6.9       0.52             2008
# ...                    ...                   ...        ...              ...
# 22745                  3.0                   5.7       0.41             2008
# 22746                  6.0                   6.7       0.59             2008
# 22747                  7.0                   5.7       0.72             2008
# 22748                  5.0                   5.9       0.52             2008
# 22749                  6.0                   7.8       0.61             2008
#
#        Month of Joining  Day of Joining
# 0                     9              30
# 1                    11              30
# 2                     3              10
# 3                    11               3
# 4                     7              24
# ...                 ...             ...
# 22745                12              30
# 22746                 1              19
# 22747                11               5
# 22748                 1              10
# 22749                 1               6
#
# [21626 rows x 10 columns]

# %%
sns.pairplot(train, hue = 'Burn Rate', palette='hls')
plt.title("Distribution of Data Points")
plt.show()

# %%
plt.figure(figsize = (15,15))
sns.heatmap(train.corr(), annot=True, fmt = '.2%')
plt.show()

# %%
y = train.iloc[:, 6].values
x= train.drop(['Burn Rate'], axis =1 ).values

# %%
print(x.shape)
print(y.shape)
# Out:
# (21626, 9)
# (21626,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc.fit_transform(x)
# Out:
# array([[-0.95159988,  0.7288022 , -1.08417483, ...,  0.        ,
#          0.7238327 ,  1.62233089],
#        [ 1.05086184,  0.7288022 ,  0.92236046, ...,  0.        ,
#          1.30499497,  1.62233089],
#        [-0.95159988, -1.37211441,  0.92236046, ...,  0.        ,
#         -1.01965413, -0.65572248],
#        ...,
#        [ 1.05086184,  0.7288022 ,  0.92236046, ...,  0.        ,
#          1.30499497, -1.22523582],
#        [-0.95159988,  0.7288022 , -1.08417483, ...,  0.        ,
#         -1.6008164 , -0.65572248],
#        [ 1.05086184, -1.37211441, -1.08417483, ...,  0.        ,
#         -1.6008164 , -1.11133316]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr_score = lr.score(x,y)

# %%
test
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe31003300390039003000      2008-12-10  Female      Service
# 1      fffe31003300310037003800      2008-08-14  Female      Product
# 2      fffe33003400380035003900      2008-11-13    Male      Product
# 3          fffe3100370039003200      2008-02-07  Female      Service
# 4      fffe32003600390036003700      2008-07-17  Female      Product
# ...                         ...             ...     ...          ...
# 12245      fffe3900310034003700      2008-10-02  Female      Service
# 12246  fffe32003600330034003000      2008-03-31  Female      Product
# 12247  fffe31003800340039003000      2008-02-12    Male      Service
# 12248  fffe32003600380031003800      2008-02-06    Male      Service
# 12249  fffe32003100390037003800      2008-08-05  Female      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  5.0
# 1                     Yes          1.0                  2.0
# 2                     Yes          1.0                  3.0
# 3                      No          3.0                  6.0
# 4                      No          2.0                  5.0
# ...                   ...          ...                  ...
# 12245                 Yes          1.0                  2.0
# 12246                 Yes          2.0                  4.0
# 12247                  No          4.0                  7.0
# 12248                  No          3.0                  6.0
# 12249                  No          2.0                  2.0
#
#        Mental Fatigue Score
# 0                       7.7
# 1                       5.2
# 2                       5.9
# 3                       4.6
# 4                       6.4
# ...                     ...
# 12245                   6.1
# 12246                   5.9
# 12247                   9.6
# 12248                   6.7
# 12249                   2.0
#
# [12250 rows x 8 columns]

# %%
test['Date of Joining'] = pd.to_datetime(test['Date of Joining'])
import datetime as dt

# %%
def get_y_m(df):
    df['Year of Joining'] = df['Date of Joining'].dt.year
    df['Month of Joining'] = df['Date of Joining'].dt.month
    df['Day of Joining']= df['Date of Joining'].dt.day
    return df

# %%
test = get_y_m(test)

# %%
test
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe31003300390039003000      2008-12-10  Female      Service
# 1      fffe31003300310037003800      2008-08-14  Female      Product
# 2      fffe33003400380035003900      2008-11-13    Male      Product
# 3          fffe3100370039003200      2008-02-07  Female      Service
# 4      fffe32003600390036003700      2008-07-17  Female      Product
# ...                         ...             ...     ...          ...
# 12245      fffe3900310034003700      2008-10-02  Female      Service
# 12246  fffe32003600330034003000      2008-03-31  Female      Product
# 12247  fffe31003800340039003000      2008-02-12    Male      Service
# 12248  fffe32003600380031003800      2008-02-06    Male      Service
# 12249  fffe32003100390037003800      2008-08-05  Female      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  5.0
# 1                     Yes          1.0                  2.0
# 2                     Yes          1.0                  3.0
# 3                      No          3.0                  6.0
# 4                      No          2.0                  5.0
# ...                   ...          ...                  ...
# 12245                 Yes          1.0                  2.0
# 12246                 Yes          2.0                  4.0
# 12247                  No          4.0                  7.0
# 12248                  No          3.0                  6.0
# 12249                  No          2.0                  2.0
#
#        Mental Fatigue Score  Year of Joining  Month of Joining  Day of Joining
# 0                       7.7             2008                12              10
# 1                       5.2             2008                 8              14
# 2                       5.9             2008                11              13
# 3                       4.6             2008                 2               7
# 4                       6.4             2008                 7              17
# ...                     ...              ...               ...             ...
# 12245                   6.1             2008                10               2
# 12246                   5.9             2008                 3              31
# 12247                   9.6             2008                 2              12
# 12248                   6.7             2008                 2               6
# 12249                   2.0             2008                 8               5
#
# [12250 rows x 11 columns]

# %%
test.drop(columns = ['Date of Joining'], inplace =True)

# %%
test['Gender'] = le.fit_transform(test['Gender'])
test['WFH Setup Available'] = le.fit_transform(test['WFH Setup Available'])
test['Company Type'] = le.fit_transform(test['Company Type'])

# %%
test
# Out:
#                     Employee ID  Gender  Company Type  WFH Setup Available  \
# 0      fffe31003300390039003000       0             1                    0
# 1      fffe31003300310037003800       0             0                    1
# 2      fffe33003400380035003900       1             0                    1
# 3          fffe3100370039003200       0             1                    0
# 4      fffe32003600390036003700       0             0                    0
# ...                         ...     ...           ...                  ...
# 12245      fffe3900310034003700       0             1                    1
# 12246  fffe32003600330034003000       0             0                    1
# 12247  fffe31003800340039003000       1             1                    0
# 12248  fffe32003600380031003800       1             1                    0
# 12249  fffe32003100390037003800       0             0                    0
#
#        Designation  Resource Allocation  Mental Fatigue Score  \
# 0              2.0                  5.0                   7.7
# 1              1.0                  2.0                   5.2
# 2              1.0                  3.0                   5.9
# 3              3.0                  6.0                   4.6
# 4              2.0                  5.0                   6.4
# ...            ...                  ...                   ...
# 12245          1.0                  2.0                   6.1
# 12246          2.0                  4.0                   5.9
# 12247          4.0                  7.0                   9.6
# 12248          3.0                  6.0                   6.7
# 12249          2.0                  2.0                   2.0
#
#        Year of Joining  Month of Joining  Day of Joining
# 0                 2008                12              10
# 1                 2008                 8              14
# 2                 2008                11              13
# 3                 2008                 2               7
# 4                 2008                 7              17
# ...                ...               ...             ...
# 12245             2008                10               2
# 12246             2008                 3              31
# 12247             2008                 2              12
# 12248             2008                 2               6
# 12249             2008                 8               5
#
# [12250 rows x 10 columns]

# %%
x_test = test.drop(columns=['Employee ID'], axis=1).values

# %%
x_test
# Out:
# array([[0.000e+00, 1.000e+00, 0.000e+00, ..., 2.008e+03, 1.200e+01,
#         1.000e+01],
#        [0.000e+00, 0.000e+00, 1.000e+00, ..., 2.008e+03, 8.000e+00,
#         1.400e+01],
#        [1.000e+00, 0.000e+00, 1.000e+00, ..., 2.008e+03, 1.100e+01,
#         1.300e+01],
#        ...,
#        [1.000e+00, 1.000e+00, 0.000e+00, ..., 2.008e+03, 2.000e+00,
#         1.200e+01],
#        [1.000e+00, 1.000e+00, 0.000e+00, ..., 2.008e+03, 2.000e+00,
#         6.000e+00],
#        [0.000e+00, 0.000e+00, 0.000e+00, ..., 2.008e+03, 8.000e+00,
#         5.000e+00]])

# %%
sc.fit_transform(x_test)
# Out:
# array([[-0.94905122,  0.72834385, -1.08757644, ...,  0.        ,
#          1.58312674, -0.64685327],
#        [-0.94905122, -1.37297789,  0.9194756 , ...,  0.        ,
#          0.43001613, -0.19361569],
#        [ 1.05368391, -1.37297789,  0.9194756 , ...,  0.        ,
#          1.29484909, -0.30692509],
#        ...,
#        [ 1.05368391,  0.72834385, -1.08757644, ...,  0.        ,
#         -1.29964979, -0.42023448],
#        [ 1.05368391,  0.72834385, -1.08757644, ...,  0.        ,
#         -1.29964979, -1.10009084],
#        [-0.94905122, -1.37297789, -1.08757644, ...,  0.        ,
#          0.43001613, -1.21340023]])

# %%
from sklearn.tree import DecisionTreeRegressor
ds=DecisionTreeRegressor()

# %%
ds.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
ds_score = ds.score(x,y)

# %%
from sklearn.ensemble import RandomForestRegressor
lf = RandomForestRegressor(max_depth=19)

# %%
lf.fit(x,y)
# Out:
# RandomForestRegressor(max_depth=19)

# %%
lf_score = lf.score(x,y)

# %%
from tabulate import tabulate

# %%
table = []
table.append(['S.no.', 'Regression Model', 'Score'])
table.append(['1', 'Linear Regression', lr_score])
table.append(['2', 'Decision Tree Regressor', ds_score])
table.append(['3', 'Random Forest Regressor', lf_score])
print(tabulate(table, headers='firstrow', tablefmt = 'fancy_grid'))
# Out:
# ╒═════════╤═════════════════════════╤══════════╕
# │   S.no. │ Regression Model        │    Score │
# ╞═════════╪═════════════════════════╪══════════╡
# │       1 │ Linear Regression       │ 0.870693 │
# ├─────────┼─────────────────────────┼──────────┤
# │       2 │ Decision Tree Regressor │ 0.998862 │
# ├─────────┼─────────────────────────┼──────────┤
# │       3 │ Random Forest Regressor │ 0.979904 │
# ╘═════════╧═════════════════════════╧══════════╛

# %%
pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
y_pred = ds.predict(x_test)
y_pred1 = np.around(y_pred, 2)
y_pred1
# Out:
# array([0.68, 0.29, 0.45, ..., 0.82, 0.64, 0.14])

# %%
s=0
for i in range(len(y_pred1)):
    if y_pred1[i]<0:
        print(y_pred[i])
        s+=1
print(s)
# Out:
# 0

# %%
test
# Out:
#                     Employee ID  Gender  Company Type  WFH Setup Available  \
# 0      fffe31003300390039003000       0             1                    0
# 1      fffe31003300310037003800       0             0                    1
# 2      fffe33003400380035003900       1             0                    1
# 3          fffe3100370039003200       0             1                    0
# 4      fffe32003600390036003700       0             0                    0
# ...                         ...     ...           ...                  ...
# 12245      fffe3900310034003700       0             1                    1
# 12246  fffe32003600330034003000       0             0                    1
# 12247  fffe31003800340039003000       1             1                    0
# 12248  fffe32003600380031003800       1             1                    0
# 12249  fffe32003100390037003800       0             0                    0
#
#        Designation  Resource Allocation  Mental Fatigue Score  \
# 0              2.0                  5.0                   7.7
# 1              1.0                  2.0                   5.2
# 2              1.0                  3.0                   5.9
# 3              3.0                  6.0                   4.6
# 4              2.0                  5.0                   6.4
# ...            ...                  ...                   ...
# 12245          1.0                  2.0                   6.1
# 12246          2.0                  4.0                   5.9
# 12247          4.0                  7.0                   9.6
# 12248          3.0                  6.0                   6.7
# 12249          2.0                  2.0                   2.0
#
#        Year of Joining  Month of Joining  Day of Joining
# 0                 2008                12              10
# 1                 2008                 8              14
# 2                 2008                11              13
# 3                 2008                 2               7
# 4                 2008                 7              17
# ...                ...               ...             ...
# 12245             2008                10               2
# 12246             2008                 3              31
# 12247             2008                 2              12
# 12248             2008                 2               6
# 12249             2008                 8               5
#
# [12250 rows x 10 columns]

# %%
Emp_id = test['Employee ID'].values

# %%
print(y_pred1.shape)
print(Emp_id.shape)
# Out:
# (12250,)
# (12250,)

# %%
out = pd.DataFrame(list(zip( Emp_id, y_pred1)), columns = ['Employee ID', 'Burn Rate'])

# %%
output = out.to_csv('submission.csv', index = False)

# %%
out
# Out:
#                     Employee ID  Burn Rate
# 0      fffe31003300390039003000       0.68
# 1      fffe31003300310037003800       0.29
# 2      fffe33003400380035003900       0.45
# 3          fffe3100370039003200       0.40
# 4      fffe32003600390036003700       0.59
# ...                         ...        ...
# 12245      fffe3900310034003700       0.36
# 12246  fffe32003600330034003000       0.51
# 12247  fffe31003800340039003000       0.82
# 12248  fffe32003600380031003800       0.64
# 12249  fffe32003100390037003800       0.14
#
# [12250 rows x 2 columns]
